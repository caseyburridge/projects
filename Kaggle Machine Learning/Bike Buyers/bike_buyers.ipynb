# %% [markdown]
# ## Udemy - gentle intro to machine learning with scikitlearn
# ### Predictive modelling project using supervised learning
# Predicting whether or not a person will buy a bike using the XGBOOST Classifier

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import os
mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-5.3.0-posix-seh-rt_v4-rev0\\mingw64\\bin'
os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']
import xgboost as xgb

# %%
data = "C:\\Users\\Casey\\Desktop\\DS projects\\Gentle-intro-project\\BBC.csv"
data_set = pd.read_csv(data) 
data_set.head(10)
# Out:
#    MaritalStatus  Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0              5       1         90000              2                     0
# 1              5       1         60000              3                     3
# 2              5       1         60000              3                     3
# 3              5       2         70000              0                     0
# 4              5       2         80000              5                     5
# 5              5       1         70000              0                     0
# 6              5       2         70000              0                     0
# 7              5       1         60000              3                     3
# 8              5       2         60000              4                     4
# 9              5       1         70000              0                     0
#
#    EnglishEducation  HouseOwnerFlag  NumberCarsOwned  CommuteDistance  Region  \
# ...

# %%
data_set.shape
# Out:
# (18484, 12)

# %%
data_set.describe()
# Out:
#        MaritalStatus        Gender   YearlyIncome  TotalChildren  \
# count   18484.000000  18484.000000   18484.000000   18484.000000
# mean        3.310106      1.494103   57305.777970       1.844352
# std         1.426147      0.499979   32285.841703       1.612408
# min         1.000000      1.000000   10000.000000       0.000000
# 25%         2.000000      1.000000   30000.000000       0.000000
# 50%         3.000000      1.000000   60000.000000       2.000000
# 75%         5.000000      2.000000   70000.000000       3.000000
# max         5.000000      2.000000  170000.000000       5.000000
#
#        NumberChildrenAtHome  EnglishEducation  HouseOwnerFlag  \
# count          18484.000000      18484.000000    18484.000000
# mean               1.004058          3.310106        0.676369
# std                1.522660          1.426147        0.467874
# min                0.000000          1.000000        0.000000
# 25%                0.000000          2.000000        0.000000
# ...

# %%
array = data_set.values
X = array[:,0:11]
Y = array[:,11]

# %%
test_size = 0.20
seed = 7

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size, random_state = seed)

# %%
model = xgb.XGBClassifier(learning_rate = 0.5, n_estimators = 1000, early_stopping_rounds = 5)

# %%
model.fit(X_train, Y_train)
model.score(X_test, Y_test)
print('Model accuracy: ' + str(round(result * 100, 3)) + '%')
# Out:
# Model accuracy: 79.55%
