# %% [markdown]
# ## We are building our first ever neural network using Keras and Tensorflow
# ### The dataset we will be predicting on in the Pima Indian Diabetes data

# %% [markdown]
# #### Importing libraries and Tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
import sklearn as sk

# %% [markdown]
# Load data

# %%
dataset = pd.read_csv("pima-indians.csv", header=0)
data = pd.DataFrame(dataset)
print(data.head())
print(data.shape)
# Out:
#    Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 0        6      148       72       35        0     33.6    0.627       50
# 1        1       85       66       29        0     26.6    0.351       31
# 2        8      183       64        0        0     23.3    0.672       32
# 3        1       89       66       23       94     28.1    0.167       21
# 4        0      137       40       35      168     43.1    2.288       33
#
#    Column9
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# (768, 9)

# %% [markdown]
# ### Split data into input variables and target variables

# %%
array = np.array(data)
X = array[:,0:8]
Y = array[:,8]

# %%
np.random.seed(7)

# %% [markdown]
# ### Create model

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Compile model

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Fit model

# %%
model.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 768/768 [==============================] - 1s 1ms/step - loss: 3.7048 - acc: 0.5977
# Epoch 2/150
# 768/768 [==============================] - 0s 533us/step - loss: 0.9408 - acc: 0.5885
# Epoch 3/150
# 768/768 [==============================] - 0s 499us/step - loss: 0.7518 - acc: 0.6432
# Epoch 4/150
# 768/768 [==============================] - 0s 481us/step - loss: 0.7113 - acc: 0.6628
# Epoch 5/150
# 768/768 [==============================] - 0s 467us/step - loss: 0.6812 - acc: 0.6758
# Epoch 6/150
# 768/768 [==============================] - 0s 555us/step - loss: 0.6503 - acc: 0.6810
# Epoch 7/150
# 768/768 [==============================] - 0s 491us/step - loss: 0.6493 - acc: 0.6719
# Epoch 8/150
# 768/768 [==============================] - 0s 569us/step - loss: 0.6366 - acc: 0.6849
# Epoch 9/150
# 768/768 [==============================] - 0s 486us/step - loss: 0.6242 - acc: 0.6914
# Epoch 10/150
# ...

# %% [markdown]
# ### Evaluate model

# %%
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 768/768 [==============================] - 0s 204us/step
#
# acc: 79.30%
